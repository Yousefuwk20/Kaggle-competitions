# %%
# Install lazypredict to get the best models
pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (4.66.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.3.2)
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (3.3.2)
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.7.6)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (0.40.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.23.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.11.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->lazypredict) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.12
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import needed libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# # Explore the data

# %%
df = pd.read_csv("/kaggle/input/iris-flower-dataset/IRIS.csv")

# %%
def check_data(df,head=5):
    print(20*"-" + "Information".center(20) + 20*"-")
    print(df.info())
    print(20*"-" + "Data Shape".center(20) + 20*"-")
    print(df.shape)
    print("\n" + 20*"-" + "The First 5 Data".center(20) + 20*"-")
    print(df.head())
    print("\n" + 20 * "-" + "The Last 5 Data".center(20) + 20 * "-")
    print(df.tail())
    print("\n" + 20 * "-" + "Missing Values".center(20) + 20 * "-")
    print(df.isnull().sum())
    print("\n" + 40 * "-" + "Describe the Data".center(40) + 40 * "-")
    print(df.describe([0.01, 0.05, 0.10, 0.50, 0.75, 0.90, 0.95, 0.99]).T)
    
check_data(df)
# Out:
# --------------------    Information     --------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
# --------------------     Data Shape     --------------------
# (150, 5)
#
# --------------------  The First 5 Data  --------------------
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0          5.10         3.50          1.40         0.20  Iris-setosa
# 1          4.90         3.00          1.40         0.20  Iris-setosa
# 2          4.70         3.20          1.30         0.20  Iris-setosa
# 3          4.60         3.10          1.50         0.20  Iris-setosa
# 4          5.00         3.60          1.40         0.20  Iris-setosa
#
# --------------------  The Last 5 Data   --------------------
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145          6.70         3.00          5.20         2.30  Iris-virginica
# 146          6.30         2.50          5.00         1.90  Iris-virginica
# 147          6.50         3.00          5.20         2.00  Iris-virginica
# 148          6.20         3.40          5.40         2.30  Iris-virginica
# 149          5.90         3.00          5.10         1.80  Iris-virginica
#
# --------------------   Missing Values   --------------------
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
#
# ----------------------------------------           Describe the Data            ----------------------------------------
#               count  mean  std  min   1%   5%  10%  50%  75%  90%  95%  99%  \
# sepal_length 150.00  5.84 0.83 4.30 4.40 4.60 4.80 5.80 6.40 6.90 7.25 7.70
# sepal_width  150.00  3.05 0.43 2.00 2.20 2.34 2.50 3.00 3.30 3.61 3.80 4.15
# petal_length 150.00  3.76 1.76 1.00 1.15 1.30 1.40 4.35 5.10 5.80 6.10 6.70
# petal_width  150.00  1.20 0.76 0.10 0.10 0.20 0.20 1.30 1.80 2.20 2.30 2.50
#
#               max
# sepal_length 7.90
# sepal_width  4.40
# petal_length 6.90
# petal_width  2.50

# %%
df['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # Preprocessing and splitting the data

# %%
le = LabelEncoder()
df['species'] = le.fit_transform(df['species'])

# %%
X = df.iloc[ : , :-1] # The features
y = df.iloc[ : , -1] # The Target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, shuffle=True)

# %% [markdown]
# # Create models

# %%
LC = LazyClassifier(verbose=1)
models, predictions = LC.fit(X_train, X_test, y_train, y_test)
# Out:
#  14%|█▍        | 4/29 [00:00<00:01, 15.82it/s]
# {'Model': 'AdaBoostClassifier', 'Accuracy': 0.9333333333333333, 'Balanced Accuracy': 0.9285714285714285, 'ROC AUC': None, 'F1 Score': 0.9333333333333333, 'Time taken': 0.14130640029907227}
# {'Model': 'BaggingClassifier', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9761904761904763, 'ROC AUC': None, 'F1 Score': 0.9671604938271604, 'Time taken': 0.04478764533996582}
# {'Model': 'BernoulliNB', 'Accuracy': 0.7666666666666667, 'Balanced Accuracy': 0.8333333333333334, 'ROC AUC': None, 'F1 Score': 0.758654970760234, 'Time taken': 0.016686677932739258}
# {'Model': 'CalibratedClassifierCV', 'Accuracy': 0.8666666666666667, 'Balanced Accuracy': 0.9047619047619048, 'ROC AUC': None, 'F1 Score': 0.8703703703703702, 'Time taken': 0.07138872146606445}
# {'Model': 'DecisionTreeClassifier', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9761904761904763, 'ROC AUC': None, 'F1 Score': 0.9671604938271604, 'Time taken': 0.019014596939086914}
# {'Model': 'DummyClassifier', 'Accuracy': 0.23333333333333334, 'Balanced Accuracy': 0.3333333333333333, 'ROC AUC': None, 'F1 Score': 0.08828828828828827, 'Time taken': 0.015394449234008789}
# {'Model': 'ExtraTreeClassifier', 'Accuracy': 0.9333333333333333, 'Balanced Accuracy': 0.9523809523809524, 'ROC AUC': None, 'F1 Score': 0.9349358974358973, 'Time taken': 0.016351938247680664}
#  48%|████▊     | 14/29 [00:00<00:00, 27.02it/s]
# {'Model': 'ExtraTreesClassifier', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9761904761904763, 'ROC AUC': None, 'F1 Score': 0.9671604938271604, 'Time taken': 0.16587448120117188}
# {'Model': 'GaussianNB', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9761904761904763, 'ROC AUC': None, 'F1 Score': 0.9671604938271604, 'Time taken': 0.01388096809387207}
# {'Model': 'KNeighborsClassifier', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9761904761904763, 'ROC AUC': None, 'F1 Score': 0.9671604938271604, 'Time taken': 0.018126249313354492}
# {'Model': 'LabelPropagation', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9761904761904763, 'ROC AUC': None, 'F1 Score': 0.9671604938271604, 'Time taken': 0.02287888526916504}
# {'Model': 'LabelSpreading', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9761904761904763, 'ROC AUC': None, 'F1 Score': 0.9671604938271604, 'Time taken': 0.0261690616607666}
# {'Model': 'LinearDiscriminantAnalysis', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9761904761904763, 'ROC AUC': None, 'F1 Score': 0.9671604938271604, 'Time taken': 0.02440500259399414}
# {'Model': 'LinearSVC', 'Accuracy': 0.9333333333333333, 'Balanced Accuracy': 0.9523809523809524, 'ROC AUC': None, 'F1 Score': 0.9349358974358973, 'Time taken': 0.03035259246826172}
# {'Model': 'LogisticRegression', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9761904761904763, 'ROC AUC': None, 'F1 Score': 0.9671604938271604, 'Time taken': 0.03708767890930176}
# {'Model': 'NearestCentroid', 'Accuracy': 0.9, 'Balanced Accuracy': 0.9285714285714285, 'ROC AUC': None, 'F1 Score': 0.9028235294117647, 'Time taken': 0.01971602439880371}
#  62%|██████▏   | 18/29 [00:00<00:00, 30.07it/s]
# {'Model': 'NuSVC', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9761904761904763, 'ROC AUC': None, 'F1 Score': 0.9671604938271604, 'Time taken': 0.016425132751464844}
# {'Model': 'PassiveAggressiveClassifier', 'Accuracy': 0.9333333333333333, 'Balanced Accuracy': 0.9047619047619048, 'ROC AUC': None, 'F1 Score': 0.9299999999999999, 'Time taken': 0.018419742584228516}
# {'Model': 'Perceptron', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9523809523809524, 'ROC AUC': None, 'F1 Score': 0.9659593280282935, 'Time taken': 0.016634464263916016}
# {'Model': 'QuadraticDiscriminantAnalysis', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9761904761904763, 'ROC AUC': None, 'F1 Score': 0.9671604938271604, 'Time taken': 0.01513051986694336}
# 100%|██████████| 29/29 [00:01<00:00, 25.08it/s]
# {'Model': 'RandomForestClassifier', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9761904761904763, 'ROC AUC': None, 'F1 Score': 0.9671604938271604, 'Time taken': 0.19600558280944824}
# {'Model': 'RidgeClassifier', 'Accuracy': 0.8, 'Balanced Accuracy': 0.8571428571428571, 'ROC AUC': None, 'F1 Score': 0.8027272727272726, 'Time taken': 0.020008325576782227}
# {'Model': 'RidgeClassifierCV', 'Accuracy': 0.8, 'Balanced Accuracy': 0.8571428571428571, 'ROC AUC': None, 'F1 Score': 0.8027272727272726, 'Time taken': 0.0189971923828125}
# {'Model': 'SGDClassifier', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9523809523809524, 'ROC AUC': None, 'F1 Score': 0.9659593280282935, 'Time taken': 0.018070459365844727}
# {'Model': 'SVC', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9761904761904763, 'ROC AUC': None, 'F1 Score': 0.9671604938271604, 'Time taken': 0.015551567077636719}
# {'Model': 'XGBClassifier', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9761904761904763, 'ROC AUC': None, 'F1 Score': 0.9671604938271604, 'Time taken': 0.06050610542297363}
# {'Model': 'LGBMClassifier', 'Accuracy': 0.9666666666666667, 'Balanced Accuracy': 0.9761904761904763, 'ROC AUC': None, 'F1 Score': 0.9671604938271604, 'Time taken': 0.05465507507324219}

# %%
predictions
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.97               0.98    None      0.97
# KNeighborsClassifier               0.97               0.98    None      0.97
# QuadraticDiscriminantAnalysis      0.97               0.98    None      0.97
# LogisticRegression                 0.97               0.98    None      0.97
# BaggingClassifier                  0.97               0.98    None      0.97
# LinearDiscriminantAnalysis         0.97               0.98    None      0.97
# LabelSpreading                     0.97               0.98    None      0.97
# LabelPropagation                   0.97               0.98    None      0.97
# GaussianNB                         0.97               0.98    None      0.97
# ExtraTreesClassifier               0.97               0.98    None      0.97
# RandomForestClassifier             0.97               0.98    None      0.97
# DecisionTreeClassifier             0.97               0.98    None      0.97
# SVC                                0.97               0.98    None      0.97
# XGBClassifier                      0.97               0.98    None      0.97
# NuSVC                              0.97               0.98    None      0.97
# Perceptron                         0.97               0.95    None      0.97
# SGDClassifier                      0.97               0.95    None      0.97
# LinearSVC                          0.93               0.95    None      0.93
# ExtraTreeClassifier                0.93               0.95    None      0.93
# NearestCentroid                    0.90               0.93    None      0.90
# AdaBoostClassifier                 0.93               0.93    None      0.93
# PassiveAggressiveClassifier        0.93               0.90    None      0.93
# CalibratedClassifierCV             0.87               0.90    None      0.87
# RidgeClassifier                    0.80               0.86    None      0.80
# RidgeClassifierCV                  0.80               0.86    None      0.80
# BernoulliNB                        0.77               0.83    None      0.76
# DummyClassifier                    0.23               0.33    None      0.09
#
#                                Time Taken
# Model
# LGBMClassifier                       0.05
# KNeighborsClassifier                 0.02
# QuadraticDiscriminantAnalysis        0.02
# LogisticRegression                   0.04
# BaggingClassifier                    0.04
# LinearDiscriminantAnalysis           0.02
# LabelSpreading                       0.03
# LabelPropagation                     0.02
# GaussianNB                           0.01
# ExtraTreesClassifier                 0.17
# RandomForestClassifier               0.20
# DecisionTreeClassifier               0.02
# SVC                                  0.02
# XGBClassifier                        0.06
# NuSVC                                0.02
# Perceptron                           0.02
# SGDClassifier                        0.02
# LinearSVC                            0.03
# ExtraTreeClassifier                  0.02
# NearestCentroid                      0.02
# AdaBoostClassifier                   0.14
# PassiveAggressiveClassifier          0.02
# CalibratedClassifierCV               0.07
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.02
# BernoulliNB                          0.02
# DummyClassifier                      0.02

# %% [markdown]
# # Import and evaluate the best models

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression

# %%
lgbm = LGBMClassifier()

lgbm.fit(X_train, y_train)
y_pred = lgbm.predict(X_test)

lgbm_T = round(lgbm.score(X_train, y_train) * 100, 2)
lgbm_accuracy = accuracy_score(y_test, y_pred)

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(45.722222222222214, 0.5, 'Truth')

# %%
knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

knn_T = round(knn.score(X_train, y_train) * 100, 2)
knn_accuracy = accuracy_score(y_test, y_pred)

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(45.722222222222214, 0.5, 'Truth')

# %%
qda = QuadraticDiscriminantAnalysis()

qda.fit(X_train, y_train)
y_pred = qda.predict(X_test)

qda_T = round(qda.score(X_train, y_train) * 100, 2)
qda_accuracy = accuracy_score(y_test, y_pred)

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(45.722222222222214, 0.5, 'Truth')

# %%
logreg = LogisticRegression()

logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)

log = round(logreg.score(X_train, y_train) * 100, 2)
log_accuracy = accuracy_score(y_test, y_pred)

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(45.722222222222214, 0.5, 'Truth')

# %%
models = pd.DataFrame({
    'Model': ['KNN', 'Logistic Regression', 
              'QuadraticDiscriminantAnalysis', 'LGBMClassifier'],
    
    'Testing_score': [knn_accuracy, log_accuracy,
                       qda_accuracy, lgbm_accuracy],
    
    'Traning_score' : [knn_T, log, qda_T, lgbm_T]})

models.sort_values(by='Testing_score', ascending=False)
# Out:
#                            Model  Testing_score  Traning_score
# 0                            KNN           0.97          97.50
# 1            Logistic Regression           0.97          98.33
# 2  QuadraticDiscriminantAnalysis           0.97          99.17
# 3                 LGBMClassifier           0.97         100.00
